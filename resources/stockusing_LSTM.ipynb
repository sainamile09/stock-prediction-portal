# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (1.5.2)
# Requirement already satisfied: pandas>=1.3.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from yfinance) (3.0.5)
# Requirement already satisfied: numpy>=1.16.5 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: requests>=2.31 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from yfinance) (2.34.2)
# Requirement already satisfied: multitasking>=0.0.7 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from yfinance) (0.0.13)
# Requirement already satisfied: platformdirs>=2.0.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from yfinance) (4.11.0)
# Requirement already satisfied: pytz>=2022.5 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from yfinance) (2026.3.post1)
# Requirement already satisfied: peewee>=3.16.2 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from yfinance) (4.2.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from yfinance) (4.15.0)
# Requirement already satisfied: curl_cffi>=0.15 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from yfinance) (0.15.0)
# Requirement already satisfied: protobuf>=3.19.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from yfinance) (7.35.1)
# Requirement already satisfied: websockets>=13.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from yfinance) (16.1.1)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.9.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.16.0)
# Requirement already satisfied: cffi>=2.0.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from curl_cffi>=0.15->yfinance) (2.1.0)
# Requirement already satisfied: certifi>=2024.2.2 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from curl_cffi>=0.15->yfinance) (2026.7.22)
# Requirement already satisfied: rich in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from curl_cffi>=0.15->yfinance) (15.0.0)
# Requirement already satisfied: pycparser in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from pandas>=1.3.0->yfinance) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from requests>=2.31->yfinance) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from requests>=2.31->yfinance) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from requests>=2.31->yfinance) (2.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.15->yfinance) (0.1.2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
from datetime import datetime

# %%
ticker = "AAPL"
now = datetime.now()
start = datetime(now.year - 10 , now.month,now.day)
end = now
df = yf.download(ticker,start,end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2016-07-29   23.723373   23.800775   23.602719   23.718821  110934800
# 2016-08-01   24.142252   24.165017   23.768907   23.768907  152671600
# 2016-08-02   23.784836   24.146798   23.675563   24.142246  135266400
# 2016-08-03   24.083057   24.094439   23.850854   23.859960  120810400
# 2016-08-04   24.231833   24.261587   24.096791   24.165456  109634800
# ...                ...         ...         ...         ...        ...
# 2026-07-23  321.660004  323.299988  319.350006  321.730011   40840800
# 2026-07-24  333.019989  334.369995  321.619995  321.790009   47489400
# 2026-07-27  336.910004  339.570007  334.019989  334.540009   49604300
# 2026-07-28  340.079987  342.890015  335.600006  340.029999   51698400
# 2026-07-29  341.040009  343.670013  339.519989  339.690002   18762041
#
# [2513 rows x 5 columns]

# %%
df.head
# Out:
# <bound method NDFrame.head of Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2016-07-29   23.723373   23.800775   23.602719   23.718821  110934800
# 2016-08-01   24.142252   24.165017   23.768907   23.768907  152671600
# 2016-08-02   23.784836   24.146798   23.675563   24.142246  135266400
# 2016-08-03   24.083057   24.094439   23.850854   23.859960  120810400
# 2016-08-04   24.231833   24.261587   24.096791   24.165456  109634800
# ...                ...         ...         ...         ...        ...
# 2026-07-23  321.660004  323.299988  319.350006  321.730011   40840800
# 2026-07-24  333.019989  334.369995  321.619995  321.790009   47489400
# 2026-07-27  336.910004  339.570007  334.019989  334.540009   49604300
# 2026-07-28  340.079987  342.890015  335.600006  340.029999   51698400
# 2026-07-29  341.040009  343.670013  339.519989  339.690002   18762041
#
# [2513 rows x 5 columns]>

# %%
df.head()
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2016-07-29  23.723373  23.800775  23.602719  23.718821  110934800
# 2016-08-01  24.142252  24.165017  23.768907  23.768907  152671600
# 2016-08-02  23.784836  24.146798  23.675563  24.142246  135266400
# 2016-08-03  24.083057  24.094439  23.850854  23.859960  120810400
# 2016-08-04  24.231833  24.261587  24.096791  24.165456  109634800

# %%
df.tail()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2026-07-23  321.660004  323.299988  319.350006  321.730011  40840800
# 2026-07-24  333.019989  334.369995  321.619995  321.790009  47489400
# 2026-07-27  336.910004  339.570007  334.019989  334.540009  49604300
# 2026-07-28  340.079987  342.890015  335.600006  340.029999  51698400
# 2026-07-29  341.040009  343.670013  339.519989  339.690002  18762041

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df.isna().sum()
# Out:
# Price   Ticker
# Close   AAPL      0
# High    AAPL      0
# Low     AAPL      0
# Open    AAPL      0
# Volume  AAPL      0
# dtype: int64

# %%
df.dropna()
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2016-07-29   23.723373   23.800775   23.602719   23.718821  110934800
# 2016-08-01   24.142252   24.165017   23.768907   23.768907  152671600
# 2016-08-02   23.784836   24.146798   23.675563   24.142246  135266400
# 2016-08-03   24.083057   24.094439   23.850854   23.859960  120810400
# 2016-08-04   24.231833   24.261587   24.096791   24.165456  109634800
# ...                ...         ...         ...         ...        ...
# 2026-07-23  321.660004  323.299988  319.350006  321.730011   40840800
# 2026-07-24  333.019989  334.369995  321.619995  321.790009   47489400
# 2026-07-27  336.910004  339.570007  334.019989  334.540009   49604300
# 2026-07-28  340.079987  342.890015  335.600006  340.029999   51698400
# 2026-07-29  341.040009  343.670013  339.519989  339.690002   18762041
#
# [2513 rows x 5 columns]

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker         AAPL         AAPL         AAPL         AAPL          AAPL
# count   2513.000000  2513.000000  2513.000000  2513.000000  2.513000e+03
# mean     128.765102   130.056211   127.347627   128.636204  9.505850e+07
# std       79.171271    79.949105    78.314669    79.074328  5.441603e+07
# min       23.604687    23.800775    23.467363    23.494830  1.791060e+07
# 25%       46.629913    47.378789    46.309547    46.803855  5.596920e+07
# 50%      133.012466   134.526803   131.191795   132.798807  8.332260e+07
# 75%      185.275055   186.490561   182.669117   184.796383  1.151172e+08
# max      341.040009   343.670013   339.519989   340.029999  4.479400e+08

# %%
df.dtypes
# Out:
# Price   Ticker
# Close   AAPL      float64
# High    AAPL      float64
# Low     AAPL      float64
# Open    AAPL      float64
# Volume  AAPL        int64
# dtype: object

# %%
df = df.reset_index()

# %%
df.head()
# Out:
# Price        Date      Close       High        Low       Open     Volume
# Ticker                  AAPL       AAPL       AAPL       AAPL       AAPL
# 0      2016-07-29  23.723373  23.800775  23.602719  23.718821  110934800
# 1      2016-08-01  24.142252  24.165017  23.768907  23.768907  152671600
# 2      2016-08-02  23.784836  24.146798  23.675563  24.142246  135266400
# 3      2016-08-03  24.083057  24.094439  23.850854  23.859960  120810400
# 4      2016-08-04  24.231833  24.261587  24.096791  24.165456  109634800

# %%
plt.figure(figsize=(12,5))
plt.plot(df.Close)
plt.title(ticker)
plt.xlabel('days')
plt.ylabel('close price')
# Out:
# Text(0, 0.5, 'close price')

# %%
df['ma_100'] = df.Close.rolling(100).mean()
plt.plot(df['ma_100'],'r')

# %%
df['ma_200'] = df.Close.rolling(200).mean()
plt.plot(df['ma_200'],'g')

# %%
df.head()
# Out:
# Price        Date      Close       High        Low       Open     Volume  \
# Ticker                  AAPL       AAPL       AAPL       AAPL       AAPL
# 0      2016-07-29  23.723373  23.800775  23.602719  23.718821  110934800
# 1      2016-08-01  24.142252  24.165017  23.768907  23.768907  152671600
# 2      2016-08-02  23.784836  24.146798  23.675563  24.142246  135266400
# 3      2016-08-03  24.083057  24.094439  23.850854  23.859960  120810400
# 4      2016-08-04  24.231833  24.261587  24.096791  24.165456  109634800
#
# Price  ma_100 ma_200
# Ticker
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN    NaN
# 3         NaN    NaN
# 4         NaN    NaN

# %%
df['percentage changed'] = df.Close.pct_change()
df[['Close','percentage changed']]
# Out:
# Price        Close percentage changed
# Ticker        AAPL
# 0        23.723373                NaN
# 1        24.142252           0.017657
# 2        23.784836          -0.014805
# 3        24.083057           0.012538
# 4        24.231833           0.006178
# ...            ...                ...
# 2508    321.660004          -0.012980
# 2509    333.019989           0.035317
# 2510    336.910004           0.011681
# 2511    340.079987           0.009409
# 2512    341.040009           0.002823
#
# [2513 rows x 2 columns]

# %%
plt.figure(figsize=(12,5))
plt.plot(df['percentage changed'])

# %%
import pandas as pd

# %%
df.shape
# Out:
# (2513, 9)

# %%
data_training = pd.DataFrame(df.Close[0:int(len(df)*0.7)])
data_testing = pd.DataFrame(df.Close[int(len(df)*0.7):int(len(df))])

# %%
data_training
# Out:
# Ticker        AAPL
# 0        23.723373
# 1        24.142252
# 2        23.784836
# 3        24.083057
# 4        24.231833
# ...            ...
# 1754    190.459885
# 1755    189.286346
# 1756    190.085129
# 1757    190.943100
# 1758    191.810959
#
# [1759 rows x 1 columns]

# %%
data_testing
# Out:
# Ticker        AAPL
# 1759    190.548660
# 1760    193.122574
# 1761    193.733994
# 1762    192.905594
# 1763    189.917526
# ...            ...
# 2508    321.660004
# 2509    333.019989
# 2510    336.910004
# 2511    340.079987
# 2512    341.040009
#
# [754 rows x 1 columns]

# %%
df
# Out:
# Price        Date       Close        High         Low        Open     Volume  \
# Ticker                   AAPL        AAPL        AAPL        AAPL       AAPL
# 0      2016-07-29   23.723373   23.800775   23.602719   23.718821  110934800
# 1      2016-08-01   24.142252   24.165017   23.768907   23.768907  152671600
# 2      2016-08-02   23.784836   24.146798   23.675563   24.142246  135266400
# 3      2016-08-03   24.083057   24.094439   23.850854   23.859960  120810400
# 4      2016-08-04   24.231833   24.261587   24.096791   24.165456  109634800
# ...           ...         ...         ...         ...         ...        ...
# 2508   2026-07-23  321.660004  323.299988  319.350006  321.730011   40840800
# 2509   2026-07-24  333.019989  334.369995  321.619995  321.790009   47489400
# 2510   2026-07-27  336.910004  339.570007  334.019989  334.540009   49604300
# 2511   2026-07-28  340.079987  342.890015  335.600006  340.029999   51698400
# 2512   2026-07-29  341.040009  343.670013  339.519989  339.690002   18762041
#
# Price       ma_100      ma_200 percentage changed
# Ticker
# 0              NaN         NaN                NaN
# 1              NaN         NaN           0.017657
# 2              NaN         NaN          -0.014805
# 3              NaN         NaN           0.012538
# 4              NaN         NaN           0.006178
# ...            ...         ...                ...
# 2508    284.301279  275.278160          -0.012980
# 2509    284.986716  275.663430           0.035317
# 2510    285.720744  276.069198           0.011681
# 2511    286.498760  276.482938           0.009409
# 2512    287.308656  276.921522           0.002823
#
# [2513 rows x 9 columns]

# %%
data_testing
# Out:
# Ticker        AAPL
# 1759    190.548660
# 1760    193.122574
# 1761    193.733994
# 1762    192.905594
# 1763    189.917526
# ...            ...
# 2508    321.660004
# 2509    333.019989
# 2510    336.910004
# 2511    340.079987
# 2512    341.040009
#
# [754 rows x 1 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler(feature_range=(0,1))

# %%
data_training_array = scaler.fit_transform(data_training)
type(data_training_array)
# Out:
# numpy.ndarray

# %%
x_train = []
y_train = []

for i in range(100,data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i,0])

# %%
x_train,y_train = np.array(x_train),np.array(y_train)

# %%
x_train
# Out:
# array([[[7.03128543e-04],
#         [3.18466631e-03],
#         [1.06724666e-03],
#         ...,
#         [1.80134288e-02],
#         [1.82178723e-02],
#         [1.91310490e-02]],
#
#        [[3.18466631e-03],
#         [1.06724666e-03],
#         [2.83398340e-03],
#         ...,
#         [1.82178723e-02],
#         [1.91310490e-02],
#         [1.95535295e-02]],
#
#        [[1.06724666e-03],
#         [2.83398340e-03],
#         [3.71536304e-03],
#         ...,
#         [1.91310490e-02],
#         [1.95535295e-02],
#         [1.97034525e-02]],
#
#        ...,
#
#        [[7.20189507e-01],
#         [7.07937402e-01],
#         [7.11438107e-01],
#         ...,
#         [1.00000000e+00],
#         [9.88490505e-01],
#         [9.81538181e-01]],
#
#        [[7.07937402e-01],
#         [7.11438107e-01],
#         [7.41309352e-01],
#         ...,
#         [9.88490505e-01],
#         [9.81538181e-01],
#         [9.86270360e-01]],
#
#        [[7.11438107e-01],
#         [7.41309352e-01],
#         [7.57645582e-01],
#         ...,
#         [9.81538181e-01],
#         [9.86270360e-01],
#         [9.91353189e-01]]], shape=(1659, 100, 1))

# %%
x_train.ndim
# Out:
# 3

# %%
x_train.shape
# Out:
# (1659, 100, 1)

# %%
y_train.shape
# Out:
# (1659,)

# %%
y_train.ndim
# Out:
# 1

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (7.35.1)
# Requirement already satisfied: requests<3,>=2.21.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (2.34.2)
# Requirement already satisfied: setuptools in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (83.0.0)
# Requirement already satisfied: six>=1.12.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (4.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (1.83.0)
# Requirement already satisfied: keras>=3.12.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (3.15.0)
# Requirement already satisfied: numpy>=1.26.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (2.4.6)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.7.22)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\ProgramData\anaconda3\envs\stockenv\Lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras.models import Sequential
from keras.layers import Dense,LSTM,Input

# %%
model = Sequential()
model.add(Input(shape=(100,1)))
model.add(LSTM(units=128,activation='tanh',return_sequences=True))
model.add(LSTM(units=64))
model.add(Dense(25))
model.add(Dense(1))

# %%
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(x_train,y_train,epochs=50)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 17s 170ms/step - loss: 0.0108
# Epoch 2/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 9s 171ms/step - loss: 8.0706e-04
# Epoch 3/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 9s 172ms/step - loss: 7.0035e-04
# Epoch 4/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 9s 176ms/step - loss: 6.2320e-04
# Epoch 5/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 9s 170ms/step - loss: 5.8148e-04
# Epoch 6/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 9s 167ms/step - loss: 5.6628e-04
# Epoch 7/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 9s 169ms/step - loss: 5.6466e-04
# Epoch 8/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 9s 166ms/step - loss: 5.2805e-04
# Epoch 9/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 4.9871e-04
# Epoch 10/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 4.8315e-04
# Epoch 11/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 4.5764e-04
# Epoch 12/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 4.8951e-04
# Epoch 13/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 4.0932e-04
# Epoch 14/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 4.5699e-04
# Epoch 15/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 3.8643e-04
# Epoch 16/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 4.1415e-04
# Epoch 17/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 3.5597e-04
# Epoch 18/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 3.5516e-04
# Epoch 19/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 5.0987e-04
# Epoch 20/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - loss: 3.0632e-04
# Epoch 21/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - loss: 3.2155e-04
# Epoch 22/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - loss: 3.1847e-04
# Epoch 23/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 3.1047e-04
# Epoch 24/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - loss: 2.7570e-04
# Epoch 25/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - loss: 2.8747e-04
# Epoch 26/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - loss: 3.1754e-04
# Epoch 27/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 191ms/step - loss: 2.9282e-04
# Epoch 28/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 193ms/step - loss: 2.4026e-04
# Epoch 29/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 191ms/step - loss: 2.5572e-04
# Epoch 30/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - loss: 2.6381e-04
# Epoch 31/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - loss: 2.6556e-04
# Epoch 32/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 189ms/step - loss: 2.1788e-04
# Epoch 33/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 189ms/step - loss: 2.1853e-04
# Epoch 34/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - loss: 2.3298e-04
# Epoch 35/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 187ms/step - loss: 2.0307e-04
# Epoch 36/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 9s 172ms/step - loss: 2.4389e-04
# Epoch 37/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 9s 168ms/step - loss: 2.0717e-04
# Epoch 38/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 9s 178ms/step - loss: 2.0503e-04
# Epoch 39/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - loss: 2.0826e-04
# Epoch 40/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 190ms/step - loss: 2.1590e-04
# Epoch 41/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - loss: 1.8039e-04
# Epoch 42/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - loss: 2.3161e-04
# Epoch 43/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 184ms/step - loss: 2.0388e-04
# Epoch 44/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - loss: 1.9786e-04
# Epoch 45/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 189ms/step - loss: 1.7579e-04
# Epoch 46/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - loss: 1.8543e-04
# Epoch 47/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 188ms/step - loss: 2.0917e-04
# Epoch 48/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 189ms/step - loss: 1.8692e-04
# Epoch 49/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 183ms/step - loss: 2.0964e-04
# Epoch 50/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - loss: 1.6777e-04

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 100, 128)            │          66,560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 25)                  │           1,625 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              26 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 352,859 (1.35 MB)
#  Trainable params: 117,619 (459.45 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 235,240 (918.91 KB)

# %%
model.save('stockpredict.keras')

# %%
past_100_days = data_training.tail(100)
past_100_days
# Out:
# Ticker        AAPL
# 1659    148.736206
# 1660    151.493729
# 1661    149.297577
# 1662    150.548248
# 1663    148.302902
# ...            ...
# 1754    190.459885
# 1755    189.286346
# 1756    190.085129
# 1757    190.943100
# 1758    191.810959
#
# [100 rows x 1 columns]

# %%
final_df = pd.concat([past_100_days,data_testing],ignore_index=True)

# %%
final_data = scaler.fit_transform(final_df)

# %%
x_test=[]
y_test=[]
for i in range(100,final_data.shape[0]):
    x_test.append(final_data[i-100:i])
    y_test.append(final_data[i,0])

# %%
x_test,y_test = np.array(x_test),np.array(y_test)

# %%
y_predicted = model.predict(x_test)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step

# %%
y_predicted = scaler.inverse_transform(y_predicted.reshape(-1,1)).flatten()
y_test = scaler.inverse_transform(y_test.reshape(-1,1)).flatten()

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test,'b',label='original price')
plt.plot(y_predicted,'r',label='predicted price')
plt.xlabel('days')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_predicted)
mse
# Out:
# 19.05182144273904

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(4.3648392230114315)

# %%
from sklearn.metrics import r2_score

# %%
r2 = r2_score(y_test,y_predicted)
r2
# Out:
# 0.9879352900225905
